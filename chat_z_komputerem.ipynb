# %%
# !pip install --ignore-installed PyYAML
# Out:
# Collecting PyYAML
# Installing collected packages: PyYAML
# Successfully installed PyYAML-5.1.2

# %%
# !pip install chatterbot_corpus

# %%
# !pip install -U PyYAML
# Out:
# Collecting PyYAML
#   Downloading https://files.pythonhosted.org/packages/e3/e8/b3212641ee2718d556df0f23f78de8303f068fe29cdaa7a91018849582fe/PyYAML-5.1.2.tar.gz (265kB)
#      |████████████████████████████████| 266kB 1.5MB/s eta 0:00:01
# Building wheels for collected packages: PyYAML
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.1.2-cp37-cp37m-linux_x86_64.whl size=392207 sha256=ff3ab63f71fd5b4480425087256d26d87a38a23bbe39d7b2f1a26e8129484043
#   Stored in directory: /home/igor/.cache/pip/wheels/d9/45/dd/65f0b38450c47cf7e5312883deb97d065e030c5cca0a365030
# Successfully built PyYAML
# Installing collected packages: PyYAML
#   Found existing installation: PyYAML 5.1
# ERROR: Cannot uninstall 'PyYAML'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
# !pip install chatterbot -y
# Out:
# Collecting chatterbot
#   Downloading https://files.pythonhosted.org/packages/6c/0e/dac0d82f34f86bf509cf5ef3e2dfc5aa7d444bd843a2330ceb7d854f84f2/ChatterBot-1.0.5-py2.py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 1.5MB/s eta 0:00:011
# Requirement already satisfied: pytz in /home/igor/anaconda3/lib/python3.7/site-packages (from chatterbot) (2018.9)
# Collecting python-dateutil<2.8,>=2.7 (from chatterbot)
#   Downloading https://files.pythonhosted.org/packages/74/68/d87d9b36af36f44254a8d512cbfc48369103a3b9e474be9bdfe536abfc45/python_dateutil-2.7.5-py2.py3-none-any.whl (225kB)
#      |████████████████████████████████| 235kB 3.9MB/s eta 0:00:01
# Collecting pymongo<4.0,>=3.3 (from chatterbot)
#   Downloading https://files.pythonhosted.org/packages/23/23/7666537adafcd232c88c156aa9382c859791d79bf12094005e009c2b6a3d/pymongo-3.9.0-cp37-cp37m-manylinux1_x86_64.whl (447kB)
#      |████████████████████████████████| 450kB 12.3MB/s eta 0:00:01
# Collecting pint>=0.8.1 (from chatterbot)
#   Downloading https://files.pythonhosted.org/packages/15/9d/bf177ebbc57d25e9e296addc14a1303d1e34d7964af5df428a8332349c42/Pint-0.9-py2.py3-none-any.whl (138kB)
#      |████████████████████████████████| 143kB 12.6MB/s eta 0:00:01
# Collecting mathparse<0.2,>=0.1 (from chatterbot)
#   Downloading https://files.pythonhosted.org/packages/c3/e5/4910fb85950cb960fcf3f5aabe1c8e55f5c9201788a1c1302b570a7e1f84/mathparse-0.1.2-py3-none-any.whl
# Collecting sqlalchemy<1.3,>=1.2 (from chatterbot)
#   Downloading https://files.pythonhosted.org/packages/f9/67/d07cf7ac7e6dd0bc55ba62816753f86d7c558107104ca915e730c9ec2512/SQLAlchemy-1.2.19.tar.gz (5.7MB)
#      |████████████████████████████████| 5.7MB 4.8MB/s eta 0:00:01
# Requirement already satisfied: nltk<4.0,>=3.2 in /home/igor/anaconda3/lib/python3.7/site-packages (from chatterbot) (3.4)
# Collecting spacy<2.2,>=2.1 (from chatterbot)
#   Downloading https://files.pythonhosted.org/packages/16/f3/554271be8ff46471586d164bfbb6999364ba30ca5a0045e2a86da5f3b2c5/spacy-2.1.9-cp37-cp37m-manylinux1_x86_64.whl (30.8MB)
#      |████████████████████████████████| 30.8MB 4.5MB/s eta 0:00:01
# Requirement already satisfied: pyyaml<5.2,>=5.1 in /home/igor/anaconda3/lib/python3.7/site-packages (from chatterbot) (5.1)
# Requirement already satisfied: six>=1.5 in /home/igor/anaconda3/lib/python3.7/site-packages (from python-dateutil<2.8,>=2.7->chatterbot) (1.12.0)
# Requirement already satisfied: singledispatch in /home/igor/anaconda3/lib/python3.7/site-packages (from nltk<4.0,>=3.2->chatterbot) (3.4.0.3)
# Collecting thinc<7.1.0,>=7.0.8 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/36/42/d7ea7539af3852fd8c1f0b3adf4a100fb3d72b40b69cef1a764ff979a743/thinc-7.0.8-cp37-cp37m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 10.6MB/s eta 0:00:01
# Collecting preshed<2.1.0,>=2.0.1 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/bc/2b/3ecd5d90d2d6fd39fbc520de7d80db5d74defdc2d7c2e15531d9cc3498c7/preshed-2.0.1-cp37-cp37m-manylinux1_x86_64.whl (82kB)
#      |████████████████████████████████| 92kB 10.9MB/s eta 0:00:01
# Collecting blis<0.3.0,>=0.2.2 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/fa/5f/47b7b29ad202b2210020e2f33bfb06d1db2abe0e709c2a84736e8a9d1bd5/blis-0.2.4-cp37-cp37m-manylinux1_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 10.7MB/s eta 0:00:01
# Collecting plac<1.0.0,>=0.9.6 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/9e/9b/62c60d2f5bc135d2aa1d8c8a86aaf84edb719a59c7f11a4316259e61a298/plac-0.9.6-py2.py3-none-any.whl
# Collecting srsly<1.1.0,>=0.0.6 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/00/5a/9a3288b648a0c5c86d0a2ef972b0a8062ff1088658da8165b370564ef346/srsly-0.2.0-cp37-cp37m-manylinux1_x86_64.whl (185kB)
#      |████████████████████████████████| 194kB 13.3MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in /home/igor/anaconda3/lib/python3.7/site-packages (from spacy<2.2,>=2.1->chatterbot) (1.16.2)
# Collecting wasabi<1.1.0,>=0.2.0 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/3f/35/6dc35bc3b49e160a016e420eb4bdcf1c887db6fd33a463959c06a508c339/wasabi-0.4.0-py3-none-any.whl
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/igor/anaconda3/lib/python3.7/site-packages (from spacy<2.2,>=2.1->chatterbot) (2.21.0)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/e1/79/6ce05ecf4d50344e29749ea7db7ddf427589228fb8fe89b29718c38c27c5/cymem-2.0.3-cp37-cp37m-manylinux1_x86_64.whl
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<2.2,>=2.1->chatterbot)
#   Downloading https://files.pythonhosted.org/packages/73/fc/10eeacb926ec1e88cd62f79d9ac106b0a3e3fe5ff1690422d88c29bd0909/murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/igor/anaconda3/lib/python3.7/site-packages (from thinc<7.1.0,>=7.0.8->spacy<2.2,>=2.1->chatterbot) (4.31.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/igor/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.2,>=2.1->chatterbot) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/igor/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.2,>=2.1->chatterbot) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/igor/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.2,>=2.1->chatterbot) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/igor/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.2,>=2.1->chatterbot) (1.24.1)
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.2.19-cp37-cp37m-linux_x86_64.whl size=1155880 sha256=9de4a76b79f9a88f65a82302e30704f20335ebc1a13046f6550c573592c28d1f
#   Stored in directory: /home/igor/.cache/pip/wheels/2c/90/a7/3b40c6cc468abff357b38fd075429920bd0d313659d889cf8a
# Successfully built sqlalchemy
# Installing collected packages: python-dateutil, pymongo, pint, mathparse, sqlalchemy, cymem, preshed, plac, srsly, blis, wasabi, murmurhash, thinc, spacy, chatterbot
#   Found existing installation: python-dateutil 2.8.0
#     Uninstalling python-dateutil-2.8.0:
#       Successfully uninstalled python-dateutil-2.8.0
#   Found existing installation: SQLAlchemy 1.3.1
#     Uninstalling SQLAlchemy-1.3.1:
#       Successfully uninstalled SQLAlchemy-1.3.1
# Successfully installed blis-0.2.4 chatterbot-1.0.5 cymem-2.0.3 mathparse-0.1.2 murmurhash-1.0.2 pint-0.9 plac-0.9.6 preshed-2.0.1 pymongo-3.9.0 python-dateutil-2.7.5 spacy-2.1.9 sqlalchemy-1.2.19 srsly-0.2.0 thinc-7.0.8 wasabi-0.4.0

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer

chatbot = ChatBot('Ron Obvious') #ytworzymy obiekt chatbot -- agent

# Create a new trainer for the chatbot
trainer = ChatterBotCorpusTrainer(chatbot)

# Train the chatbot based on the english corpus
trainer.train("chatterbot.corpus.english")

# Get a response to an input statement
chatbot.get_response("Hello, how are you today?")
# Out:
# [nltk_data] Downloading package stopwords to /home/igor/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/igor/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /home/igor/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# Training ai.yml: [                    ] 1%
# /home/igor/anaconda3/lib/python3.7/site-packages/chatterbot/corpus.py:38: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(data_file)
# Training ai.yml: [####################] 100%
# Training botprofile.yml: [####################] 100%
# Training computers.yml: [####################] 100%
# Training conversations.yml: [####################] 100%
# Training emotion.yml: [####################] 100%
# Training food.yml: [####################] 100%
# Training gossip.yml: [####################] 100%
# Training greetings.yml: [####################] 100%
# Training health.yml: [####################] 100%
# Training history.yml: [####################] 100%
# Training humor.yml: [####################] 100%
# Training literature.yml: [####################] 100%
# Training money.yml: [####################] 100%
# Training movies.yml: [####################] 100%
# Training politics.yml: [####################] 100%
# Training psychology.yml: [####################] 100%
# Training science.yml: [####################] 100%
# Training sports.yml: [####################] 100%
# Training trivia.yml: [####################] 100%
# <Statement text:Is it cramped in the computer>

# %%
resp = chatbot.get_response("Hello, how are you today?")

# %%
resp = chatbot.get_response("A motormouth")
resp.text
# Out:
# 'A ratchet-jaw.'

# %%
conversation = [
    "Hello",
    "Hi there!",
    "How are you doing?",
    "I'm doing great.",
    "That is good to hear",
    "Thank you.",
    "You're welcome.",
    "have fun",
    "what is your name?",
    "my name is Ono",
    "and my name is Ono",
    "what software you are running?",
    "I am runnig ROS",
    "are you having fun?",
    "yes,I am having fun here",
    "what are you doing?",
    "I am teaching ROS",
    "what do you do?",
    "I am teaching ROS for a living",
    "what do you do?",
    "I am teaching ROS right now, but I am free in the evening",
    "do you speak Chinese?",
    "I speak Python"
    ]

# %% [markdown]
# ### Definicja i trenowanie chatbota
#
# 1. coś robię
# 2. i coś jeszcze

# %%
from chatterbot.trainers import ListTrainer
from chatterbot import ChatBot
import chatterbot
import chatterbot.languages
#from chatterbot.trainers import ChatterBotCorpusTrainer

chatbot = ChatBot('Agent Franek') #ytworzymy obiekt chatbot -- agent
'''chatbot = ChatBot("Agent Matematyczny", logic_adapters=[
    
    
    {"import_path":"chatterbot.logic.BestMatch"},{
        "import_path":"chatterbot.logic.MathematicalEvaluation",
        "language":"chatterbot.languages.POL"}
    ])
'''
trainer = ListTrainer(chatbot)
trainer.train(conversation)

resp = chatbot.get_response("I am teaching ROS for a living")
print(resp.text)
# Out:
# List Trainer: [#                   ] 4%
# [nltk_data] Downloading package stopwords to /home/igor/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/igor/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# List Trainer: [####################] 100%
# what do you do?

# %%
while True:
    print("\n")
    tekst_usera = input(resp.text)
    resp = chatbot.get_response(tekst_usera)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-a4acc589578d> in <module>
#       1 while True:
#       2     print("\n")
# ----> 3     tekst_usera = input(chatbot.get_latest_response())
#       4     resp = chatbot.get_response(tekst_usera)
#
# TypeError: get_latest_response() missing 1 required positional argument: 'conversation'

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /home/igor/anaconda3/lib/python3.7/site-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
while True:
    print("\n")
    tekst_usera = input(resp.text)
    resp = chatbot.get_response(tekst_usera)
    doc = nlp(tekst_usera)
    print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
    lista_wszystkich_czasownikow= [token.lemma_ for token in doc if token.pos_ == "VERB"]
    print("Verbs:", lista_wszystkich_czasownikow )
    
    # Find named entities, phrases and concepts
    for entity in doc.ents:
        print(entity.text, entity.label_)
# Out:
# my name is OnoI eat hotdogs
# Noun phrases: ['I', 'hotdogs']
# Verbs: ['eat']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-368d74590bf0> in <module>
#       3 while True:
#       4     print("\n")
# ----> 5     tekst_usera = input(resp.text)
#       6     resp = chatbot.get_response(tekst_usera)
#       7     doc = nlp(tekst_usera)
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %%
chatbot.logic_adapters.append

# %%
"franek" in ["zenon", "franek"]
# Out:
# True
